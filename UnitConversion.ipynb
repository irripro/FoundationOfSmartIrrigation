# %%
WMETER_TO_PSI = 1.4219702
# GAL_TO_LT = 3.785411
PSI_TO_KPA = 6.894757
IN_TO_MM = 25.4


class Measure(object):
    units = []
    conversion = [[]]

    def __init__(self, value=None, unit=None):
        self.values = {}
        if unit:
            self.set_single_value(value, unit)

    def set_single_value(self, value, unit):
        """
        Define the values for the whole list of possible units
        :param value: the referential value
        :type value: float
        :param unit: the referential unit
        :type unit: str
        :return:
        """
        u_index = self.__class__.units.index(unit)
        conversion_factors = self.__class__.conversion[u_index]
        for cont in range(len(self.__class__.units)):
            current_unit = self.__class__.units[cont]
            self.values[current_unit] = value * conversion_factors[cont]


class Pressure(Measure):
    """
    This class will serve to instantiate _pressure measures
    """
    units = ['psi', 'Pa', 'kPa', 'mH2O']
    conversion = [[1, 1000 * PSI_TO_KPA, PSI_TO_KPA, 1 / WMETER_TO_PSI],
                  [0.001 / PSI_TO_KPA, 1, 1e-3,
                   PSI_TO_KPA * 1000 / WMETER_TO_PSI],
                  [1 / PSI_TO_KPA, 1e3, 1, PSI_TO_KPA / WMETER_TO_PSI],
                  [WMETER_TO_PSI, 9806.38, 9.80638, 1]]


class Length(Measure):
    """
    Serves to instantiate elevation or length measures
    """
    units = ['m', 'ft', 'in', 'mm']
    ft_to_mm = IN_TO_MM * 12
    conversion = [[1, 1000 / ft_to_mm, 1000 / IN_TO_MM, 1000],
                  [ft_to_mm / 1000, 1, 12.0, ft_to_mm],
                  [IN_TO_MM / 1000, 1 / 12.0, 1, IN_TO_MM],
                  [0.001, 1 / ft_to_mm, 1 / IN_TO_MM, 1]]


class Volume(Measure):
    units = ['lt', 'gal', 'm3']
    GAL_TO_LT = 3.785411
    conversion = [[1, 1 / GAL_TO_LT, 0.001],
                  [GAL_TO_LT, 1, GAL_TO_LT / 1000],
                  [1000, 1000 / GAL_TO_LT, 1]]


class Time(Measure):
    units = ['min', 'hr']
    conversion = [[1, 1 / 60.0],
                  [60.0, 1]]


class VolFlow(Measure):
    """
    Serves to instantiate volumetric flows
    """
    units = ['gpm', 'm3/H', 'lpm']
    gal_index = Volume.units.index('gal')
    m3_index = Volume.units.index('m3')
    gal_to_m3 = Volume.conversion[gal_index][m3_index]
    conversion = [[1, gal_to_m3 * 60, Volume.conversion[1][0]],
                  [Volume.conversion[2][1] * Time.conversion[0][1], 1,
                   1000 / 60.0],
                  [1 / Volume.GAL_TO_LT, 60 / 1000.0, 1]]


class NozzleK(Measure):
    units = ['gpm/psi^0.5', 'lpm/bar^0.5']
    psi_index = Pressure.units.index('psi')
    kPa_index = Pressure.units.index('kPa')
    psi_to_kPa = Pressure.conversion[psi_index][kPa_index]
    conversion = [[1, Volume.GAL_TO_LT * (100 / psi_to_kPa) ** .5],
                  [((psi_to_kPa / 100) ** .5) / Volume.GAL_TO_LT, 1]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       4 import matplotlib.pyplot as plt
#       6 # 创建一个wntr水网络模型
# ----> 7 wn = wntr.network.WaterNetworkModel("ExampleNetwork.inp")  # 假设network.inp是你的EPANET INP文件路径
#       9 # 将wntr的水网络转换为networkx的图
#      10 G = wntr.network.to_nx(wn)
#
# File c:\Python312\Lib\site-packages\wntr\network\model.py:83, in WaterNetworkModel.__init__(self, inp_file_name)
#      81 self._inpfile = None
#      82 if inp_file_name:
# ---> 83     read_inpfile(inp_file_name, append=self)
#      85 # To be deleted and/or renamed and/or moved
#      86 # Time parameters
#      87 self.sim_time = 0.0
#
# File c:\Python312\Lib\site-packages\wntr\network\io.py:514, in read_inpfile(filename, append)
#     497 """
#     498 Create or append a WaterNetworkModel from an EPANET INP file
#     499
#    (...)
#     511
#     512 """
#     513 inpfile = wntr.epanet.InpFile()
# --> 514 wn = inpfile.read(filename, wn=append)
#     515 wn._inpfile = inpfile
#     517 return wn
#
# File c:\Python312\Lib\site-packages\wntr\epanet\io.py:334, in InpFile.read(self, inp_files, wn)
#     331 self._read_patterns()
#     333 ### JUNCTIONS
# --> 334 self._read_junctions()
#     336 ### RESERVOIRS
#     337 self._read_reservoirs()
#
# File c:\Python312\Lib\site-packages\wntr\epanet\io.py:526, in InpFile._read_junctions(self)
#     524 base_demand = 0.0
#     525 if len(current) > 2:
# --> 526     base_demand = to_si(self.flow_units, float(current[2]), HydParam.Demand)
#     527 self.wn.add_junction(current[0],
#     528                 base_demand,
#     529                 pat,
#     530                 to_si(self.flow_units, float(current[1]), HydParam.Elevation),
#     531                 demand_category=None)
#
# File c:\Python312\Lib\site-packages\wntr\epanet\util.py:1295, in to_si(from_units, data, param, mass_units, pressure_units, darcy_weisbach, reaction_order)
#    1223 """Convert an EPANET parameter from internal to SI standard units.
#    1224
#    1225 .. note::
#    (...)
#    1292
#    1293 """
#    1294 if isinstance(param, HydParam):
# -> 1295     return param._to_si(from_units, data, darcy_weisbach)
#    1296 elif isinstance(param, QualParam):
#    1297     return param._to_si(from_units, data, mass_units, reaction_order)
#
# File c:\Python312\Lib\site-packages\wntr\epanet\util.py:560, in HydParam._to_si(self, flow_units, data, darcy_weisbach)
#     558 # Do conversions
#     559 if self in [HydParam.Demand, HydParam.Flow, HydParam.EmitterCoeff]:
# --> 560     data = data * flow_units.factor
#     561     if self is HydParam.EmitterCoeff:
#     562         if flow_units.is_traditional:
#     563             # flowunit/sqrt(psi) to flowunit/sqrt(m), i.e.,
#     564             # flowunit/sqrt(psi) * sqrt(psi/ft / m/ft ) = flowunit/sqrt(m)
#
# AttributeError: 'NoneType' object has no attribute 'factor'
